# %%
import pandas as pd
import numpy as np

df = pd.read_csv('datasets/question_2/MedQuAD/All-2479-Answers-retrieved-from-MedQuAD.csv')

# %%
import nlp_profiler.core as nlpprof

new_text_column_dataset = nlpprof.apply_text_profiling(df, 'Answer')
# Out:
# Granular features:   0%|                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      | 0/4 [00:00<?, ?it/s]
# ...

# %%
new_text_column_dataset
# Out:
#                                                  Answer  sentences_count  \
# 0     Question: What is (are) Polycystic ovary syndr...                3
# 1     Question: What causes Polycystic ovary syndrom...               16
# 2     Question: What causes Noonan syndrome ?\nURL: ...                6
# 3     Question: What are the complications of Noonan...                2
# 4     Question: How to prevent Noonan syndrome ?\nUR...                2
# ...                                                 ...              ...
# 2474  Question: What should I do if I forget a dose ...                6
# 2475  Question: What are the side effects or risks o...               10
# 2476  Question: What to do in case of emergency or o...                4
# 2477  Question: What other information should I know...               12
# 2478  Question: What should I know about storage and...                5
#
#       characters_count  spaces_count  count_words  duplicates_count  \
# ...

# %%
st = new_text_column_dataset.describe()[['count_words','noun_phase_count','spelling_quality_score','ease_of_reading_score']].to_latex()

# %%
print(st)
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# {} &  count\_words &  noun\_phase\_count &  spelling\_quality\_score &  ease\_of\_reading\_score \\
# \midrule
# count &  2479.000000 &       2479.000000 &             2479.000000 &            2479.000000 \\
# mean  &   217.838241 &         92.845099 &                0.935186 &              48.845724 \\
# std   &   230.866930 &         96.384337 &                0.040636 &              21.901488 \\
# min   &    20.000000 &          8.000000 &                0.694444 &             -48.970000 \\
# 25\%   &    72.000000 &         32.000000 &                0.914508 &              37.600000 \\
# 50\%   &   135.000000 &         56.000000 &                0.943601 &              52.560000 \\
# 75\%   &   259.000000 &        116.000000 &                0.964532 &              64.810000 \\
# max   &  1876.000000 &        905.000000 &                0.996558 &              96.180000 \\
# \bottomrule
# \end{tabular}

# %%
new_text_column_dataset.describe().to_csv('profile.csv')

# %%
new_text_column_dataset.to_csv('full_profile.csv')
